# %%
# %pip install xgboost
# %pip install catboost
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from scipy.sparse import hstack
import warnings

warnings.simplefilter(action='ignore')
# warnings.resetwarnings() to reset

# %% [markdown]
# ## VECTORIZATION
# ### TFIDF

# %%
df_train = pd.read_csv("cleaned_data.csv", index_col=0)
df_train.head()
# Out:
#                                                 Text Author  length  \
# 0  Scoring in PROC DISCRIM is as easy as validati...     AM     215
# 1  In the GLM procedure, you may have used LSMEAN...     AM     782
# 2  The first problem, accuracy of the data file, ...     AM     990
# 3  If the homogeneity of covariance matrices assu...     AM     934
# 4  With a CONTRAST statement, you specify L, in t...     AM    1490
#
#                                    preprocessed_text
# 0  ['scoring', 'proc', 'discrim', 'easy', 'valida...
# 1  ['glm', 'procedure', 'may', 'used', 'lsmeans',...
# 2  ['first', 'problem', 'accuracy', 'data', 'file...
# 3  ['homogeneity', 'covariance', 'matrix', 'assum...
# 4  ['contrast', 'statement', 'specify', 'l', 'cas...

# %%
df_train.shape
# Out:
# (816, 4)

# %%
X = df_train[["length", "preprocessed_text"]]
y = df_train[["Author"]]

# %%
# train test split on dataset

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=1, stratify=y, shuffle=True)

# %% [markdown]
# <div class="alert alert-info" role="alert">
# Creating a validation set from the training data helps ensure that the final test set remains completely unseen, avoiding any data leakage and giving a true measure of the model's performance.
# </div>

# %%
vectorizer = TfidfVectorizer()
X_train_tfidf = vectorizer.fit_transform(X_train['preprocessed_text'])
vectorizer.get_feature_names_out()
# Out:
# array(['0average', '10th', '10unit', ..., 'zero', 'zip', 'zscores'],
#       dtype=object)

# %% [markdown]
# <div class="alert alert-info" role="alert">
#     The reason TFIDF was used over bag of words is because bag of words just creates a set of embeddings which show the word occurrences whereas TF-IDF shows the relative importance of a term to a document in a collection of documents. While bag of words is easy to interpret, majority of the time TF-IDF performs better in machine learning models
# </div>
#
# <div class="alert alert-danger" role="alert">
# array(['0average', '0no', '10th', ..., 'zip', 'zscores', 'zt'],
#       dtype=object)
# YOU DIDNT CLEAN PROPERLY
# </div>

# %%
scaler = StandardScaler()
X_train_length_scaled = scaler.fit_transform(X_train[['length']])
X_train_length_scaled[:5] # printing first 5 responses
# Out:
# array([[-0.48717892],
#        [ 1.11741945],
#        [ 0.73314064],
#        [ 1.78475241],
#        [-0.89957569]])

# %% [markdown]
# <div class="alert alert-info" role="alert">
# TF-IDF gives out normalized values, this means the other features used should also be scaled to ensure that they are contributing appropriately.
# </div>

# %%
# Combine TF-IDF feature with 'length' feature
X_train_combined = hstack([X_train_tfidf, X_train_length_scaled])
X_train_combined
# Out:
# <612x5690 sparse matrix of type '<class 'numpy.float64'>'
# 	with 26959 stored elements in COOrdinate format>

# %%
# Doing the same for validation set
X_val_tfidf = vectorizer.transform(X_val['preprocessed_text'])
X_val_length_scaled = scaler.transform(X_val[['length']])

X_val_combined = hstack([X_val_tfidf, X_val_length_scaled])

# %%
X_val_combined
# Out:
# <204x5690 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8125 stored elements in COOrdinate format>

# %% [markdown]
# ## IMPLEMENTING LOGISTIC REGRESSION MODEL

# %%
logreg = LogisticRegression()
logreg.fit(X_train_combined, y_train)
# Out:
# LogisticRegression()

# %%
y_val_pred = logreg.predict(X_val_combined)

report = classification_report(y_val, y_val_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           AM       1.00      0.62      0.77        16
#           CD       0.84      0.93      0.88        44
#           DM       0.92      0.94      0.93        36
#           DO       0.92      0.75      0.83        16
#           FE       0.94      0.97      0.96        35
#           TK       0.97      1.00      0.98        57
#
#     accuracy                           0.92       204
#    macro avg       0.93      0.87      0.89       204
# weighted avg       0.93      0.92      0.92       204

# %% [markdown]
# <div class="alert alert-info" role="alert">
# Since the data is imbalanced, we will be looking at the weighted avg f1 score as the main metric as it multiplies the F1-Score by the proportion of the samples that belong to each author class.
# </div>

# %% [markdown]
# ## IMPLEMENTING NAIVE BAYES MODEL

# %%
from sklearn.naive_bayes import ComplementNB
from sklearn.preprocessing import MinMaxScaler

# complement naive bayes will be implemented due to the class imbalance

cnb = ComplementNB()

# ValueError: Negative values in data passed to ComplementNB (input X)
# This means that the data has to be scaled to 0 to 1 range, need to use minmaxscaler


scaler = MinMaxScaler()
X_train_dense = X_train_combined.toarray()
X_train_scaled = scaler.fit_transform(X_train_dense)


# fitting the data on the model
cnb.fit(X_train_scaled, y_train)
# Out:
# ComplementNB()

# %%
y_val_pred = cnb.predict(X_val_combined)

report = classification_report(y_val, y_val_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#           AM       1.00      0.75      0.86        16
#           CD       0.89      0.95      0.92        44
#           DM       0.97      1.00      0.99        36
#           DO       0.94      0.94      0.94        16
#           FE       0.97      0.97      0.97        35
#           TK       1.00      1.00      1.00        57
#
#     accuracy                           0.96       204
#    macro avg       0.96      0.94      0.95       204
# weighted avg       0.96      0.96      0.96       204

# %% [markdown]
# <div class="alert alert-info" role="alert">
# Naive bayes seems to be performing much better in almost all categories, which is a good sign.
# </div>

# %% [markdown]
# ## IMPLEMENTING SVM MODEL

# %%
from sklearn import svm

svm_clf = svm.SVC()
svm_clf.fit(X_train_combined, y_train)
# Out:
# SVC()

# %%
y_val_pred = svm_clf.predict(X_val_combined)

# %% [markdown]
# <div class="alert alert-info" role="alert">
# Not the best weighted avg f1 score, we can train on different kernels to see if there is a particular one that performs better
# </div>

# %%
from sklearn import svm
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split

# Define the kernels to test
kernels = ['linear', 'rbf', 'poly', 'sigmoid']

# Train and evaluate an SVM with each kernel
for kernel in kernels:
    print(f"{kernel} is being used:")
    clf = svm.SVC(kernel=kernel)
    clf.fit(X_train_combined, y_train)
    y_val_pred = clf.predict(X_val_combined)

    # Evaluate the model
    print(classification_report(y_val, y_val_pred))
    print("======================================================")
# Out:
# linear is being used:
#               precision    recall  f1-score   support
#
#           AM       1.00      0.69      0.81        16
#           CD       0.86      0.95      0.90        44
#           DM       0.97      1.00      0.99        36
#           DO       0.93      0.81      0.87        16
#           FE       0.97      1.00      0.99        35
#           TK       1.00      1.00      1.00        57
#
#     accuracy                           0.95       204
#    macro avg       0.96      0.91      0.93       204
# weighted avg       0.95      0.95      0.95       204
#
# ======================================================
# rbf is being used:
#               precision    recall  f1-score   support
#
#           AM       1.00      0.56      0.72        16
#           CD       0.82      0.91      0.86        44
#           DM       0.94      0.94      0.94        36
#           DO       0.92      0.69      0.79        16
#           FE       0.89      0.97      0.93        35
#           TK       0.95      1.00      0.97        57
#
#     accuracy                           0.91       204
#    macro avg       0.92      0.85      0.87       204
# weighted avg       0.91      0.91      0.90       204
#
# ======================================================
# poly is being used:
#               precision    recall  f1-score   support
#
#           AM       0.00      0.00      0.00        16
#           CD       0.92      0.25      0.39        44
#           DM       1.00      0.42      0.59        36
#           DO       1.00      0.06      0.12        16
#           FE       0.80      0.11      0.20        35
#           TK       0.34      1.00      0.50        57
#
#     accuracy                           0.43       204
#    macro avg       0.68      0.31      0.30       204
# weighted avg       0.68      0.43      0.37       204
#
# ======================================================
# sigmoid is being used:
#               precision    recall  f1-score   support
#
#           AM       0.80      0.25      0.38        16
#           CD       0.42      0.77      0.54        44
#           DM       0.67      0.81      0.73        36
#           DO       0.80      0.25      0.38        16
#           FE       0.79      0.63      0.70        35
#           TK       0.90      0.67      0.77        57
#
#     accuracy                           0.64       204
#    macro avg       0.73      0.56      0.58       204
# weighted avg       0.72      0.64      0.64       204
#
# ======================================================

# %% [markdown]
# <div class="alert alert-info" role="alert">
# The linear kernel performs the best with a weighted average f1 score of 95%. With further hyperparameter tuning, these models will be able to perform much better. Before that lets try out a few other models including tree based and ensemble methods.
# </div>

# %% [markdown]
# ## DECISION TREE

# %%
from sklearn import tree

dc_clf = tree.DecisionTreeClassifier().fit(X_train_combined, y_train)
y_val_pred = dc_clf.predict(X_val_combined)
print(classification_report(y_val, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#           AM       0.40      0.38      0.39        16
#           CD       0.78      0.82      0.80        44
#           DM       0.75      0.75      0.75        36
#           DO       0.71      0.75      0.73        16
#           FE       0.64      0.71      0.68        35
#           TK       0.96      0.86      0.91        57
#
#     accuracy                           0.76       204
#    macro avg       0.71      0.71      0.71       204
# weighted avg       0.77      0.76      0.76       204

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier


rf_clf = RandomForestClassifier()
rf_clf.fit(X_train_combined, y_train)
y_val_pred = rf_clf.predict(X_val_combined)
print(classification_report(y_val, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#           AM       1.00      0.69      0.81        16
#           CD       0.85      0.93      0.89        44
#           DM       0.97      0.97      0.97        36
#           DO       0.93      0.81      0.87        16
#           FE       0.89      0.97      0.93        35
#           TK       0.98      0.98      0.98        57
#
#     accuracy                           0.93       204
#    macro avg       0.94      0.89      0.91       204
# weighted avg       0.94      0.93      0.93       204

# %% [markdown]
# ## Boosting Algorithms (GBM, Hist GBM, XGB, Adaboost, Catboost)

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold

gbm_clf = GradientBoostingClassifier()
gbm_clf.fit(X_train_combined, y_train)
y_val_pred = gbm_clf.predict(X_val_combined)
print(classification_report(y_val, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#           AM       0.92      0.69      0.79        16
#           CD       0.79      0.95      0.87        44
#           DM       0.97      0.86      0.91        36
#           DO       0.93      0.81      0.87        16
#           FE       0.86      0.91      0.89        35
#           TK       1.00      0.98      0.99        57
#
#     accuracy                           0.91       204
#    macro avg       0.91      0.87      0.89       204
# weighted avg       0.91      0.91      0.91       204

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier

hgb_clf = HistGradientBoostingClassifier()
hgb_clf.fit(X_train_combined.toarray(), y_train)
y_val_pred = hgb_clf.predict(X_val_combined.toarray())
print(classification_report(y_val, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#           AM       0.73      0.69      0.71        16
#           CD       0.86      0.84      0.85        44
#           DM       0.89      0.92      0.90        36
#           DO       0.80      0.75      0.77        16
#           FE       0.83      0.83      0.83        35
#           TK       0.95      0.98      0.97        57
#
#     accuracy                           0.87       204
#    macro avg       0.84      0.83      0.84       204
# weighted avg       0.87      0.87      0.87       204

# %%
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)

xgb_clf = XGBClassifier(objective='multi:softmax')

xgb_clf.fit(X_train_combined, y_train_encoded)

y_val_pred_encoded = xgb_clf.predict(X_val_combined)

y_val_pred = label_encoder.inverse_transform(y_val_pred_encoded)
print(classification_report(y_val, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#           AM       0.82      0.56      0.67        16
#           CD       0.78      0.91      0.84        44
#           DM       0.88      0.83      0.86        36
#           DO       0.81      0.81      0.81        16
#           FE       0.81      0.74      0.78        35
#           TK       0.95      1.00      0.97        57
#
#     accuracy                           0.86       204
#    macro avg       0.84      0.81      0.82       204
# weighted avg       0.86      0.86      0.85       204

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# Assuming X_train, y_train, X_val, and y_val are already defined

# Initialize Logistic Regression
log_reg = LogisticRegression()

# Initialize AdaBoostClassifier with Logistic Regression as the base estimator
ada_clf = AdaBoostClassifier(
    base_estimator=log_reg,
    n_estimators=1000,
    learning_rate=1.0,
    algorithm="SAMME.R"
)

# Train the model
ada_clf.fit(X_train_combined, y_train)

# Make predictions
y_val_pred = ada_clf.predict(X_val_combined)

# Print classification report
print(classification_report(y_val, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#           AM       0.85      0.69      0.76        16
#           CD       1.00      0.23      0.37        44
#           DM       1.00      0.08      0.15        36
#           DO       0.93      0.81      0.87        16
#           FE       0.23      1.00      0.38        35
#           TK       1.00      0.25      0.39        57
#
#     accuracy                           0.42       204
#    macro avg       0.83      0.51      0.49       204
# weighted avg       0.85      0.42      0.41       204

# %%
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report

# Assuming X_train, y_train, X_val, and y_val are already defined

# Initialize CatBoostClassifier
# The parameters here are basic; you might need to tune them based on your dataset
cat_clf = CatBoostClassifier()

# Train the model
cat_clf.fit(X_train_combined, y_train)

# Make predictions
y_val_pred = cat_clf.predict(X_val_combined)

# Print classification report
print(classification_report(y_val, y_val_pred))
# Out:
# Learning rate set to 0.07717
# 0:	learn: 1.7284563	total: 81.7ms	remaining: 1m 21s
# 1:	learn: 1.6855807	total: 99.7ms	remaining: 49.7s
# 2:	learn: 1.6369820	total: 118ms	remaining: 39.2s
# 3:	learn: 1.5883775	total: 137ms	remaining: 34s
# 4:	learn: 1.5479156	total: 155ms	remaining: 30.9s
# 5:	learn: 1.5118765	total: 173ms	remaining: 28.7s
# 6:	learn: 1.4842768	total: 191ms	remaining: 27.1s
# 7:	learn: 1.4457485	total: 210ms	remaining: 26.1s
# 8:	learn: 1.4111487	total: 229ms	remaining: 25.2s
# 9:	learn: 1.3799144	total: 248ms	remaining: 24.5s
# 10:	learn: 1.3515181	total: 266ms	remaining: 23.9s
# 11:	learn: 1.3241570	total: 284ms	remaining: 23.4s
# 12:	learn: 1.2937076	total: 302ms	remaining: 22.9s
# 13:	learn: 1.2692514	total: 320ms	remaining: 22.5s
# 14:	learn: 1.2525150	total: 338ms	remaining: 22.2s
# 15:	learn: 1.2313487	total: 356ms	remaining: 21.9s
# 16:	learn: 1.2153719	total: 374ms	remaining: 21.6s
# 17:	learn: 1.1977806	total: 392ms	remaining: 21.4s
# 18:	learn: 1.1768064	total: 411ms	remaining: 21.2s
# 19:	learn: 1.1565643	total: 430ms	remaining: 21.1s
# 20:	learn: 1.1339634	total: 450ms	remaining: 21s
# 21:	learn: 1.1160907	total: 469ms	remaining: 20.8s
# 22:	learn: 1.1046886	total: 487ms	remaining: 20.7s
# 23:	learn: 1.0908638	total: 506ms	remaining: 20.6s
# 24:	learn: 1.0753641	total: 524ms	remaining: 20.5s
# 25:	learn: 1.0548083	total: 543ms	remaining: 20.3s
# 26:	learn: 1.0432546	total: 562ms	remaining: 20.2s
# 27:	learn: 1.0316252	total: 582ms	remaining: 20.2s
# 28:	learn: 1.0221186	total: 601ms	remaining: 20.1s
# 29:	learn: 1.0153809	total: 620ms	remaining: 20.1s
# 30:	learn: 1.0058625	total: 640ms	remaining: 20s
# 31:	learn: 0.9954233	total: 659ms	remaining: 19.9s
# 32:	learn: 0.9830317	total: 678ms	remaining: 19.9s
# 33:	learn: 0.9744174	total: 696ms	remaining: 19.8s
# 34:	learn: 0.9629144	total: 715ms	remaining: 19.7s
# 35:	learn: 0.9494202	total: 735ms	remaining: 19.7s
# 36:	learn: 0.9405530	total: 755ms	remaining: 19.7s
# 37:	learn: 0.9306400	total: 774ms	remaining: 19.6s
# 38:	learn: 0.9194695	total: 793ms	remaining: 19.5s
# 39:	learn: 0.9097872	total: 812ms	remaining: 19.5s
# 40:	learn: 0.9012920	total: 832ms	remaining: 19.4s
# 41:	learn: 0.8924982	total: 850ms	remaining: 19.4s
# 42:	learn: 0.8805380	total: 869ms	remaining: 19.3s
# 43:	learn: 0.8678718	total: 888ms	remaining: 19.3s
# 44:	learn: 0.8596557	total: 908ms	remaining: 19.3s
# 45:	learn: 0.8514481	total: 926ms	remaining: 19.2s
# 46:	learn: 0.8436636	total: 946ms	remaining: 19.2s
# 47:	learn: 0.8369065	total: 965ms	remaining: 19.1s
# 48:	learn: 0.8285407	total: 986ms	remaining: 19.1s
# 49:	learn: 0.8229143	total: 1.01s	remaining: 19.1s
# 50:	learn: 0.8150214	total: 1.03s	remaining: 19.1s
# 51:	learn: 0.8100106	total: 1.05s	remaining: 19.1s
# 52:	learn: 0.8039777	total: 1.07s	remaining: 19.1s
# 53:	learn: 0.7964576	total: 1.09s	remaining: 19.1s
# 54:	learn: 0.7889435	total: 1.11s	remaining: 19s
# 55:	learn: 0.7811523	total: 1.13s	remaining: 19.1s
# 56:	learn: 0.7741085	total: 1.15s	remaining: 19s
# 57:	learn: 0.7697042	total: 1.17s	remaining: 19s
# 58:	learn: 0.7648811	total: 1.19s	remaining: 19s
# 59:	learn: 0.7579622	total: 1.21s	remaining: 19s
# 60:	learn: 0.7471357	total: 1.23s	remaining: 18.9s
# 61:	learn: 0.7389942	total: 1.25s	remaining: 18.9s
# 62:	learn: 0.7328980	total: 1.27s	remaining: 18.9s
# 63:	learn: 0.7264894	total: 1.29s	remaining: 18.9s
# 64:	learn: 0.7204092	total: 1.31s	remaining: 18.8s
# 65:	learn: 0.7147997	total: 1.33s	remaining: 18.8s
# 66:	learn: 0.7102352	total: 1.34s	remaining: 18.7s
# 67:	learn: 0.7025082	total: 1.36s	remaining: 18.7s
# 68:	learn: 0.6957364	total: 1.38s	remaining: 18.7s
# 69:	learn: 0.6929358	total: 1.41s	remaining: 18.7s
# 70:	learn: 0.6884644	total: 1.43s	remaining: 18.7s
# 71:	learn: 0.6842830	total: 1.45s	remaining: 18.7s
# 72:	learn: 0.6803044	total: 1.47s	remaining: 18.7s
# 73:	learn: 0.6760143	total: 1.49s	remaining: 18.6s
# 74:	learn: 0.6729165	total: 1.51s	remaining: 18.6s
# 75:	learn: 0.6684279	total: 1.53s	remaining: 18.6s
# 76:	learn: 0.6630004	total: 1.55s	remaining: 18.5s
# 77:	learn: 0.6593623	total: 1.57s	remaining: 18.5s
# 78:	learn: 0.6545496	total: 1.58s	remaining: 18.5s
# 79:	learn: 0.6498520	total: 1.6s	remaining: 18.5s
# 80:	learn: 0.6437820	total: 1.62s	remaining: 18.4s
# 81:	learn: 0.6393840	total: 1.64s	remaining: 18.4s
# 82:	learn: 0.6361891	total: 1.66s	remaining: 18.4s
# 83:	learn: 0.6317010	total: 1.68s	remaining: 18.3s
# 84:	learn: 0.6258150	total: 1.7s	remaining: 18.3s
# 85:	learn: 0.6216083	total: 1.72s	remaining: 18.3s
# 86:	learn: 0.6171012	total: 1.74s	remaining: 18.2s
# 87:	learn: 0.6125117	total: 1.75s	remaining: 18.2s
# 88:	learn: 0.6080441	total: 1.77s	remaining: 18.2s
# 89:	learn: 0.6032583	total: 1.79s	remaining: 18.1s
# 90:	learn: 0.6004508	total: 1.81s	remaining: 18.1s
# 91:	learn: 0.5953199	total: 1.83s	remaining: 18s
# 92:	learn: 0.5914180	total: 1.85s	remaining: 18s
# 93:	learn: 0.5866430	total: 1.86s	remaining: 18s
# 94:	learn: 0.5851561	total: 1.88s	remaining: 17.9s
# 95:	learn: 0.5827681	total: 1.9s	remaining: 17.9s
# 96:	learn: 0.5807129	total: 1.92s	remaining: 17.9s
# 97:	learn: 0.5767505	total: 1.94s	remaining: 17.8s
# 98:	learn: 0.5729285	total: 1.96s	remaining: 17.8s
# 99:	learn: 0.5691593	total: 1.98s	remaining: 17.8s
# 100:	learn: 0.5646283	total: 2s	remaining: 17.8s
# 101:	learn: 0.5594990	total: 2.02s	remaining: 17.8s
# 102:	learn: 0.5570491	total: 2.04s	remaining: 17.8s
# 103:	learn: 0.5533646	total: 2.06s	remaining: 17.8s
# 104:	learn: 0.5510418	total: 2.08s	remaining: 17.7s
# 437:	learn: 0.1926744	total: 8.4s	remaining: 10.8s
# 438:	learn: 0.1923731	total: 8.42s	remaining: 10.8s
# 439:	learn: 0.1914945	total: 8.44s	remaining: 10.7s
# 440:	learn: 0.1913107	total: 8.46s	remaining: 10.7s
# 441:	learn: 0.1910460	total: 8.47s	remaining: 10.7s
# 442:	learn: 0.1907877	total: 8.49s	remaining: 10.7s
# 443:	learn: 0.1904975	total: 8.51s	remaining: 10.7s
# 444:	learn: 0.1900641	total: 8.53s	remaining: 10.6s
# 445:	learn: 0.1897486	total: 8.55s	remaining: 10.6s
# 446:	learn: 0.1893062	total: 8.56s	remaining: 10.6s
# 447:	learn: 0.1891831	total: 8.58s	remaining: 10.6s
# 448:	learn: 0.1889218	total: 8.6s	remaining: 10.6s
# 449:	learn: 0.1881802	total: 8.62s	remaining: 10.5s
# 450:	learn: 0.1879929	total: 8.64s	remaining: 10.5s
# 451:	learn: 0.1876180	total: 8.66s	remaining: 10.5s
# 452:	learn: 0.1871151	total: 8.68s	remaining: 10.5s
# 453:	learn: 0.1868405	total: 8.69s	remaining: 10.5s
# 454:	learn: 0.1863745	total: 8.71s	remaining: 10.4s
# 455:	learn: 0.1852835	total: 8.73s	remaining: 10.4s
# 456:	learn: 0.1846863	total: 8.75s	remaining: 10.4s
# 457:	learn: 0.1845015	total: 8.77s	remaining: 10.4s
# 458:	learn: 0.1840595	total: 8.78s	remaining: 10.4s
# 459:	learn: 0.1838202	total: 8.8s	remaining: 10.3s
# 460:	learn: 0.1834771	total: 8.82s	remaining: 10.3s
# 461:	learn: 0.1831645	total: 8.84s	remaining: 10.3s
# 462:	learn: 0.1827802	total: 8.86s	remaining: 10.3s
# 463:	learn: 0.1824846	total: 8.88s	remaining: 10.3s
# 464:	learn: 0.1821279	total: 8.89s	remaining: 10.2s
# 465:	learn: 0.1818983	total: 8.91s	remaining: 10.2s
# 466:	learn: 0.1814620	total: 8.93s	remaining: 10.2s
# 467:	learn: 0.1811626	total: 8.95s	remaining: 10.2s
# 468:	learn: 0.1809724	total: 8.97s	remaining: 10.2s
# 469:	learn: 0.1807630	total: 8.98s	remaining: 10.1s
# 470:	learn: 0.1805935	total: 9s	remaining: 10.1s
# 471:	learn: 0.1802679	total: 9.02s	remaining: 10.1s
# 472:	learn: 0.1798859	total: 9.04s	remaining: 10.1s
# 473:	learn: 0.1795856	total: 9.06s	remaining: 10.1s
# 474:	learn: 0.1792440	total: 9.08s	remaining: 10s
# 475:	learn: 0.1790581	total: 9.1s	remaining: 10s
# 476:	learn: 0.1788981	total: 9.12s	remaining: 10s
# 477:	learn: 0.1785876	total: 9.14s	remaining: 9.98s
# 478:	learn: 0.1778722	total: 9.15s	remaining: 9.96s
# 479:	learn: 0.1776939	total: 9.18s	remaining: 9.94s
# 480:	learn: 0.1775253	total: 9.19s	remaining: 9.92s
# 481:	learn: 0.1770867	total: 9.21s	remaining: 9.9s
# 482:	learn: 0.1766644	total: 9.23s	remaining: 9.88s
# 483:	learn: 0.1764181	total: 9.25s	remaining: 9.87s
# 531:	learn: 0.1623221	total: 10.2s	remaining: 8.94s
# 532:	learn: 0.1619207	total: 10.2s	remaining: 8.93s
# 533:	learn: 0.1610244	total: 10.2s	remaining: 8.91s
# 534:	learn: 0.1608179	total: 10.2s	remaining: 8.89s
# 535:	learn: 0.1603501	total: 10.2s	remaining: 8.87s
# 536:	learn: 0.1601135	total: 10.3s	remaining: 8.85s
# 537:	learn: 0.1599980	total: 10.3s	remaining: 8.83s
# 538:	learn: 0.1595640	total: 10.3s	remaining: 8.81s
# 539:	learn: 0.1593556	total: 10.3s	remaining: 8.79s
# 540:	learn: 0.1586541	total: 10.3s	remaining: 8.78s
# 541:	learn: 0.1583787	total: 10.4s	remaining: 8.76s
# 542:	learn: 0.1581943	total: 10.4s	remaining: 8.74s
# 543:	learn: 0.1578553	total: 10.4s	remaining: 8.72s
# 544:	learn: 0.1575442	total: 10.4s	remaining: 8.7s
# 545:	learn: 0.1572156	total: 10.4s	remaining: 8.68s
# 546:	learn: 0.1570791	total: 10.5s	remaining: 8.66s
# 547:	learn: 0.1568946	total: 10.5s	remaining: 8.64s
# 548:	learn: 0.1567311	total: 10.5s	remaining: 8.62s
# 549:	learn: 0.1565348	total: 10.5s	remaining: 8.6s
# 550:	learn: 0.1559205	total: 10.5s	remaining: 8.58s
# 551:	learn: 0.1555172	total: 10.5s	remaining: 8.56s
# 552:	learn: 0.1550483	total: 10.6s	remaining: 8.54s
# 553:	learn: 0.1543466	total: 10.6s	remaining: 8.52s
# 554:	learn: 0.1541988	total: 10.6s	remaining: 8.5s
# 555:	learn: 0.1533638	total: 10.6s	remaining: 8.48s
# 556:	learn: 0.1530926	total: 10.6s	remaining: 8.46s
# 557:	learn: 0.1526186	total: 10.7s	remaining: 8.45s
# 558:	learn: 0.1522558	total: 10.7s	remaining: 8.43s
# 559:	learn: 0.1519711	total: 10.7s	remaining: 8.41s
# 560:	learn: 0.1514762	total: 10.7s	remaining: 8.39s
# 561:	learn: 0.1513165	total: 10.7s	remaining: 8.37s
# 562:	learn: 0.1512319	total: 10.8s	remaining: 8.35s
# 563:	learn: 0.1509835	total: 10.8s	remaining: 8.33s
# 564:	learn: 0.1507669	total: 10.8s	remaining: 8.31s
# 565:	learn: 0.1501101	total: 10.8s	remaining: 8.29s
# 566:	learn: 0.1499517	total: 10.8s	remaining: 8.27s
# 567:	learn: 0.1497702	total: 10.9s	remaining: 8.25s
# 568:	learn: 0.1494286	total: 10.9s	remaining: 8.23s
# 569:	learn: 0.1491998	total: 10.9s	remaining: 8.21s
# 570:	learn: 0.1487909	total: 10.9s	remaining: 8.19s
# 571:	learn: 0.1486902	total: 10.9s	remaining: 8.17s
# 572:	learn: 0.1482977	total: 10.9s	remaining: 8.15s
# 573:	learn: 0.1480487	total: 11s	remaining: 8.14s
# 574:	learn: 0.1478977	total: 11s	remaining: 8.12s
# 575:	learn: 0.1477560	total: 11s	remaining: 8.1s
# 576:	learn: 0.1475821	total: 11s	remaining: 8.08s
# 577:	learn: 0.1473960	total: 11s	remaining: 8.06s
# 578:	learn: 0.1468737	total: 11.1s	remaining: 8.04s
# 768:	learn: 0.1086796	total: 14.6s	remaining: 4.38s
# 769:	learn: 0.1085834	total: 14.6s	remaining: 4.36s
# 770:	learn: 0.1083083	total: 14.6s	remaining: 4.34s
# 771:	learn: 0.1080728	total: 14.6s	remaining: 4.32s
# 772:	learn: 0.1078293	total: 14.7s	remaining: 4.3s
# 773:	learn: 0.1076982	total: 14.7s	remaining: 4.29s
# 774:	learn: 0.1074163	total: 14.7s	remaining: 4.27s
# 775:	learn: 0.1073602	total: 14.7s	remaining: 4.25s
# 776:	learn: 0.1072963	total: 14.7s	remaining: 4.23s
# 777:	learn: 0.1070087	total: 14.8s	remaining: 4.21s
# 778:	learn: 0.1067765	total: 14.8s	remaining: 4.19s
# 779:	learn: 0.1066585	total: 14.8s	remaining: 4.17s
# 780:	learn: 0.1065831	total: 14.8s	remaining: 4.15s
# 781:	learn: 0.1065326	total: 14.8s	remaining: 4.13s
# 782:	learn: 0.1064587	total: 14.8s	remaining: 4.12s
# 783:	learn: 0.1062930	total: 14.9s	remaining: 4.1s
# 784:	learn: 0.1061733	total: 14.9s	remaining: 4.08s
# 785:	learn: 0.1060224	total: 14.9s	remaining: 4.06s
# 786:	learn: 0.1055402	total: 14.9s	remaining: 4.04s
# 787:	learn: 0.1052516	total: 14.9s	remaining: 4.02s
# 788:	learn: 0.1050828	total: 15s	remaining: 4s
# 789:	learn: 0.1050063	total: 15s	remaining: 3.98s
# 790:	learn: 0.1049174	total: 15s	remaining: 3.96s
# 791:	learn: 0.1047495	total: 15s	remaining: 3.94s
# 792:	learn: 0.1045628	total: 15s	remaining: 3.93s
# 793:	learn: 0.1044472	total: 15.1s	remaining: 3.91s
# 794:	learn: 0.1043978	total: 15.1s	remaining: 3.89s
# 795:	learn: 0.1042336	total: 15.1s	remaining: 3.87s
# 796:	learn: 0.1041255	total: 15.1s	remaining: 3.85s
# 797:	learn: 0.1040601	total: 15.2s	remaining: 3.83s
# 798:	learn: 0.1037629	total: 15.2s	remaining: 3.82s
# 799:	learn: 0.1034899	total: 15.2s	remaining: 3.8s
# 800:	learn: 0.1034378	total: 15.2s	remaining: 3.78s
# 801:	learn: 0.1032631	total: 15.2s	remaining: 3.76s
# 802:	learn: 0.1030891	total: 15.3s	remaining: 3.74s
# 803:	learn: 0.1029306	total: 15.3s	remaining: 3.72s
# 804:	learn: 0.1027862	total: 15.3s	remaining: 3.7s
# 805:	learn: 0.1026993	total: 15.3s	remaining: 3.69s
# 806:	learn: 0.1025913	total: 15.3s	remaining: 3.67s
# 807:	learn: 0.1024899	total: 15.3s	remaining: 3.65s
# 808:	learn: 0.1024051	total: 15.4s	remaining: 3.63s
# 809:	learn: 0.1023230	total: 15.4s	remaining: 3.61s
# 810:	learn: 0.1020460	total: 15.4s	remaining: 3.59s
# 811:	learn: 0.1019141	total: 15.4s	remaining: 3.57s
# 812:	learn: 0.1018273	total: 15.4s	remaining: 3.55s
# 813:	learn: 0.1017496	total: 15.5s	remaining: 3.53s
# 814:	learn: 0.1016698	total: 15.5s	remaining: 3.51s
# 815:	learn: 0.1014093	total: 15.5s	remaining: 3.49s
# 816:	learn: 0.1012049	total: 15.5s	remaining: 3.48s
# 817:	learn: 0.1011048	total: 15.5s	remaining: 3.46s
# 818:	learn: 0.1010523	total: 15.6s	remaining: 3.44s
# 819:	learn: 0.1006531	total: 15.6s	remaining: 3.42s
# 820:	learn: 0.1005411	total: 15.6s	remaining: 3.4s
# 821:	learn: 0.1004428	total: 15.6s	remaining: 3.38s
# 822:	learn: 0.1002104	total: 15.6s	remaining: 3.36s
# 823:	learn: 0.1001119	total: 15.6s	remaining: 3.34s
# 824:	learn: 0.1000194	total: 15.7s	remaining: 3.32s
# 825:	learn: 0.0999616	total: 15.7s	remaining: 3.3s
# 826:	learn: 0.0996947	total: 15.7s	remaining: 3.28s
# 827:	learn: 0.0993105	total: 15.7s	remaining: 3.26s
# 828:	learn: 0.0990248	total: 15.7s	remaining: 3.25s
# 829:	learn: 0.0989770	total: 15.8s	remaining: 3.23s
# 830:	learn: 0.0987302	total: 15.8s	remaining: 3.21s
# 831:	learn: 0.0986720	total: 15.8s	remaining: 3.19s
# 832:	learn: 0.0985915	total: 15.8s	remaining: 3.17s
# 833:	learn: 0.0985148	total: 15.8s	remaining: 3.15s
# 834:	learn: 0.0983157	total: 15.8s	remaining: 3.13s
# 835:	learn: 0.0982600	total: 15.9s	remaining: 3.11s
# 836:	learn: 0.0981734	total: 15.9s	remaining: 3.09s
# 837:	learn: 0.0980702	total: 15.9s	remaining: 3.07s
# 838:	learn: 0.0979352	total: 15.9s	remaining: 3.05s
# 839:	learn: 0.0977106	total: 15.9s	remaining: 3.03s
# 840:	learn: 0.0976410	total: 15.9s	remaining: 3.02s
# 841:	learn: 0.0974083	total: 16s	remaining: 3s
# 842:	learn: 0.0973255	total: 16s	remaining: 2.98s
# 843:	learn: 0.0972149	total: 16s	remaining: 2.96s
# 844:	learn: 0.0971425	total: 16s	remaining: 2.94s
# 845:	learn: 0.0970779	total: 16s	remaining: 2.92s
# 846:	learn: 0.0969154	total: 16.1s	remaining: 2.9s
# 847:	learn: 0.0967465	total: 16.1s	remaining: 2.88s
# 848:	learn: 0.0966876	total: 16.1s	remaining: 2.86s
# 849:	learn: 0.0966110	total: 16.1s	remaining: 2.84s
# 850:	learn: 0.0963310	total: 16.1s	remaining: 2.82s
# 851:	learn: 0.0961496	total: 16.1s	remaining: 2.81s
# 852:	learn: 0.0960500	total: 16.2s	remaining: 2.79s
# 853:	learn: 0.0958965	total: 16.2s	remaining: 2.77s
# 854:	learn: 0.0955957	total: 16.2s	remaining: 2.75s
# 855:	learn: 0.0955298	total: 16.2s	remaining: 2.73s
# 856:	learn: 0.0954176	total: 16.2s	remaining: 2.71s
# 857:	learn: 0.0951780	total: 16.3s	remaining: 2.69s
# 858:	learn: 0.0951335	total: 16.3s	remaining: 2.67s
# 859:	learn: 0.0950468	total: 16.3s	remaining: 2.65s
# 860:	learn: 0.0948267	total: 16.3s	remaining: 2.63s
# 861:	learn: 0.0947686	total: 16.3s	remaining: 2.61s
# 862:	learn: 0.0945252	total: 16.3s	remaining: 2.6s
# 863:	learn: 0.0944161	total: 16.4s	remaining: 2.58s
# 864:	learn: 0.0942755	total: 16.4s	remaining: 2.56s
# 865:	learn: 0.0941318	total: 16.4s	remaining: 2.54s
# 866:	learn: 0.0940202	total: 16.4s	remaining: 2.52s
# 867:	learn: 0.0939281	total: 16.4s	remaining: 2.5s
# 868:	learn: 0.0938138	total: 16.5s	remaining: 2.48s
# 869:	learn: 0.0936294	total: 16.5s	remaining: 2.46s
# 870:	learn: 0.0935825	total: 16.5s	remaining: 2.44s
# 871:	learn: 0.0935225	total: 16.5s	remaining: 2.42s
# 872:	learn: 0.0934719	total: 16.5s	remaining: 2.4s
# 873:	learn: 0.0934138	total: 16.5s	remaining: 2.38s
# 874:	learn: 0.0932249	total: 16.6s	remaining: 2.37s
# 875:	learn: 0.0931663	total: 16.6s	remaining: 2.35s
# 876:	learn: 0.0930501	total: 16.6s	remaining: 2.33s
# 877:	learn: 0.0927764	total: 16.6s	remaining: 2.31s
# 878:	learn: 0.0927215	total: 16.6s	remaining: 2.29s
# 879:	learn: 0.0926587	total: 16.7s	remaining: 2.27s
# 880:	learn: 0.0924351	total: 16.7s	remaining: 2.25s
# 881:	learn: 0.0923270	total: 16.7s	remaining: 2.23s
# 882:	learn: 0.0922439	total: 16.7s	remaining: 2.21s
# 883:	learn: 0.0920739	total: 16.7s	remaining: 2.2s
# 884:	learn: 0.0920063	total: 16.8s	remaining: 2.18s
# 885:	learn: 0.0919337	total: 16.8s	remaining: 2.16s
# 886:	learn: 0.0916393	total: 16.8s	remaining: 2.14s
# 887:	learn: 0.0915826	total: 16.8s	remaining: 2.12s
# 888:	learn: 0.0915339	total: 16.8s	remaining: 2.1s
# 889:	learn: 0.0914733	total: 16.9s	remaining: 2.08s
# 890:	learn: 0.0913919	total: 16.9s	remaining: 2.06s
# 891:	learn: 0.0913144	total: 16.9s	remaining: 2.04s
# 892:	learn: 0.0910814	total: 16.9s	remaining: 2.03s
# 893:	learn: 0.0910359	total: 16.9s	remaining: 2.01s
# 894:	learn: 0.0909785	total: 16.9s	remaining: 1.99s
# 895:	learn: 0.0907716	total: 17s	remaining: 1.97s
# 896:	learn: 0.0907110	total: 17s	remaining: 1.95s
# 897:	learn: 0.0906664	total: 17s	remaining: 1.93s
# 898:	learn: 0.0905101	total: 17s	remaining: 1.91s
# 899:	learn: 0.0902765	total: 17s	remaining: 1.89s
# 900:	learn: 0.0901985	total: 17.1s	remaining: 1.87s
# 901:	learn: 0.0901248	total: 17.1s	remaining: 1.85s
# 902:	learn: 0.0900776	total: 17.1s	remaining: 1.84s
# 903:	learn: 0.0899496	total: 17.1s	remaining: 1.82s
# 904:	learn: 0.0898291	total: 17.1s	remaining: 1.8s
# 905:	learn: 0.0896441	total: 17.2s	remaining: 1.78s
# 906:	learn: 0.0895034	total: 17.2s	remaining: 1.76s
# 907:	learn: 0.0894589	total: 17.2s	remaining: 1.74s
# 908:	learn: 0.0892371	total: 17.2s	remaining: 1.72s
# 909:	learn: 0.0891656	total: 17.2s	remaining: 1.7s
# 910:	learn: 0.0890074	total: 17.3s	remaining: 1.69s
# 911:	learn: 0.0889391	total: 17.3s	remaining: 1.67s
# 912:	learn: 0.0888590	total: 17.3s	remaining: 1.65s
# 913:	learn: 0.0887232	total: 17.3s	remaining: 1.63s
# 914:	learn: 0.0886527	total: 17.3s	remaining: 1.61s
# 915:	learn: 0.0883901	total: 17.3s	remaining: 1.59s
# 916:	learn: 0.0883201	total: 17.4s	remaining: 1.57s
# 917:	learn: 0.0882238	total: 17.4s	remaining: 1.55s
# 918:	learn: 0.0881458	total: 17.4s	remaining: 1.53s
# 919:	learn: 0.0880711	total: 17.4s	remaining: 1.51s
# 920:	learn: 0.0879657	total: 17.4s	remaining: 1.5s
# 921:	learn: 0.0878954	total: 17.5s	remaining: 1.48s
# 922:	learn: 0.0878014	total: 17.5s	remaining: 1.46s
# 923:	learn: 0.0877601	total: 17.5s	remaining: 1.44s
# 924:	learn: 0.0876500	total: 17.5s	remaining: 1.42s
# 925:	learn: 0.0873737	total: 17.5s	remaining: 1.4s
# 926:	learn: 0.0872640	total: 17.6s	remaining: 1.38s
# 927:	learn: 0.0872177	total: 17.6s	remaining: 1.36s
# 928:	learn: 0.0871631	total: 17.6s	remaining: 1.34s
# 929:	learn: 0.0870846	total: 17.6s	remaining: 1.32s
# 930:	learn: 0.0870383	total: 17.6s	remaining: 1.31s
# 931:	learn: 0.0869798	total: 17.7s	remaining: 1.29s
# 932:	learn: 0.0868778	total: 17.7s	remaining: 1.27s
# 933:	learn: 0.0867944	total: 17.7s	remaining: 1.25s
# 934:	learn: 0.0866814	total: 17.7s	remaining: 1.23s
# 935:	learn: 0.0866007	total: 17.7s	remaining: 1.21s
# 936:	learn: 0.0865530	total: 17.8s	remaining: 1.19s
# 937:	learn: 0.0864304	total: 17.8s	remaining: 1.17s
# 938:	learn: 0.0862794	total: 17.8s	remaining: 1.16s
# 939:	learn: 0.0862428	total: 17.8s	remaining: 1.14s
# 940:	learn: 0.0861502	total: 17.8s	remaining: 1.12s
# 941:	learn: 0.0858168	total: 17.8s	remaining: 1.1s
# 942:	learn: 0.0857264	total: 17.9s	remaining: 1.08s
# 943:	learn: 0.0856722	total: 17.9s	remaining: 1.06s
# 944:	learn: 0.0854313	total: 17.9s	remaining: 1.04s
# 945:	learn: 0.0854010	total: 17.9s	remaining: 1.02s
# 946:	learn: 0.0853593	total: 17.9s	remaining: 1s
# 947:	learn: 0.0852340	total: 18s	remaining: 985ms
# 948:	learn: 0.0851245	total: 18s	remaining: 966ms
# 949:	learn: 0.0850082	total: 18s	remaining: 947ms
# 950:	learn: 0.0849297	total: 18s	remaining: 928ms
# 951:	learn: 0.0848404	total: 18s	remaining: 909ms
# 952:	learn: 0.0847716	total: 18.1s	remaining: 890ms
# 953:	learn: 0.0843663	total: 18.1s	remaining: 871ms
# 954:	learn: 0.0840321	total: 18.1s	remaining: 852ms
# 955:	learn: 0.0839775	total: 18.1s	remaining: 833ms
# 956:	learn: 0.0839402	total: 18.1s	remaining: 814ms
# 957:	learn: 0.0838002	total: 18.1s	remaining: 795ms
# 958:	learn: 0.0837488	total: 18.2s	remaining: 777ms
# 959:	learn: 0.0835066	total: 18.2s	remaining: 758ms
# 960:	learn: 0.0833226	total: 18.2s	remaining: 739ms
# 961:	learn: 0.0832835	total: 18.2s	remaining: 720ms
# 962:	learn: 0.0831476	total: 18.2s	remaining: 701ms
# 963:	learn: 0.0830688	total: 18.3s	remaining: 682ms
# 964:	learn: 0.0829731	total: 18.3s	remaining: 663ms
# 965:	learn: 0.0828441	total: 18.3s	remaining: 644ms
# 966:	learn: 0.0828051	total: 18.3s	remaining: 625ms
# 967:	learn: 0.0825411	total: 18.3s	remaining: 606ms
# 968:	learn: 0.0824810	total: 18.4s	remaining: 587ms
# 969:	learn: 0.0824216	total: 18.4s	remaining: 568ms
# 970:	learn: 0.0822397	total: 18.4s	remaining: 549ms
# 971:	learn: 0.0821897	total: 18.4s	remaining: 530ms
# 972:	learn: 0.0821336	total: 18.4s	remaining: 511ms
# 973:	learn: 0.0819615	total: 18.4s	remaining: 493ms
# 974:	learn: 0.0819044	total: 18.5s	remaining: 474ms
# 975:	learn: 0.0818188	total: 18.5s	remaining: 455ms
# 976:	learn: 0.0817570	total: 18.5s	remaining: 436ms
# 977:	learn: 0.0816036	total: 18.5s	remaining: 417ms
# 978:	learn: 0.0815474	total: 18.5s	remaining: 398ms
# 979:	learn: 0.0815050	total: 18.6s	remaining: 379ms
# 980:	learn: 0.0814339	total: 18.6s	remaining: 360ms
# 981:	learn: 0.0814070	total: 18.6s	remaining: 341ms
# 982:	learn: 0.0813566	total: 18.6s	remaining: 322ms
# 983:	learn: 0.0812020	total: 18.6s	remaining: 303ms
# 984:	learn: 0.0810585	total: 18.7s	remaining: 284ms
# 985:	learn: 0.0809658	total: 18.7s	remaining: 265ms
# 986:	learn: 0.0808044	total: 18.7s	remaining: 246ms
# 987:	learn: 0.0807362	total: 18.7s	remaining: 227ms
# 988:	learn: 0.0806505	total: 18.7s	remaining: 208ms
# 989:	learn: 0.0806101	total: 18.8s	remaining: 189ms
# 990:	learn: 0.0805446	total: 18.8s	remaining: 171ms
# 991:	learn: 0.0804915	total: 18.8s	remaining: 152ms
# 992:	learn: 0.0804603	total: 18.8s	remaining: 133ms
# 993:	learn: 0.0803816	total: 18.8s	remaining: 114ms
# 994:	learn: 0.0803083	total: 18.9s	remaining: 94.7ms
# 995:	learn: 0.0802623	total: 18.9s	remaining: 75.8ms
# 996:	learn: 0.0800441	total: 18.9s	remaining: 56.8ms
# 997:	learn: 0.0799919	total: 18.9s	remaining: 37.9ms
# 998:	learn: 0.0799268	total: 18.9s	remaining: 18.9ms
# 999:	learn: 0.0797579	total: 18.9s	remaining: 0us
#               precision    recall  f1-score   support
#
#           AM       0.92      0.69      0.79        16
#           CD       0.83      0.91      0.87        44
#           DM       0.94      0.92      0.93        36
#           DO       0.93      0.81      0.87        16
#           FE       0.91      0.89      0.90        35
#           TK       0.93      1.00      0.97        57
#
#     accuracy                           0.91       204
#    macro avg       0.91      0.87      0.89       204
# weighted avg       0.91      0.91      0.91       204
